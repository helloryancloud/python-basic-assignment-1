# %%
#Theory questions of  python basic assignment 1

#what is python and why is it popular?
#ANS=Python is a high-level, interpreted programming language known for its
#simple and readable syntax.
#why its popular:
#	Easy to learn and write
#	Large community support
#	Wide range of libraries (for web, data science, AI, etc.)
#	Used in many fields like web development, automation, and machine learning

#Q2 What is an interpreter in python?
#ANS=An interpreter in Python is a program that reads and runs Python code line by line.
# It converts high-level code into machine-readable instructions during execution.

#Q3 What are pre-defined keywords in python?
#ANS=Pre-defined keywords are reserved words that have special meaning in Python.
#Examples: if, else, while, for, def, class, etc.

#Q4 Can keywords be used as variable names?
#ANS=No, you cannot use keywords as variable names in Python.
#for example:if=5.

#Q5 What is mutability in python?
#ANS=Mutability refers to whether an object can be changed after it is created.
#•	Mutable objects can be modified (like lists).
#•	Immutable objects cannot be changed (like strings, tuples).

#Q6 Why are lists mutable,but tuples are immutable?
#ANS=	Lists are designed to be flexible, so you can add, remove, or change elements.
	#Tuples are meant to be fixed collections of items for safety and performance, so their contents can’t be changed.

#Q7 What is the difference between == and is operator in python?
#ANS= •	== checks if values are equal.
#is checks if both variables refer to the same object in memory.
#example a=[1,2] , b=[1,2]
# a== b is True
# a is b is False

#Q8 what are logical operator in python?
#ANS= Logical operators are used to combine conditions:
#•	and – returns True if both are True
#•	or – returns True if at least one is True
#•	not – reverses the result (True becomes False)

#Q9 What is type casting in python?
#ANS=Type casting means converting one data type into another.
#Example: a="10"
#         b=int(a)

#Q10 What is the difference between implicit and explicit type casting?
#ANS= Implicit is done automatically by Python.
#Example=5+2.0 result=7.0
# Explicit cating is done manually b the programmer.
#Example=int("10") or str(5).

#Q11 What is the purpose of conditional statement in python?
#ANS= Conditional statements are used to make decisions in code.
#They execute different blocks based on whether conditions are True or False.
#Example :
#if age>18:
#   print("adult")
#else:
#   print("minor")

#Q12 How does the elif statement work?
#ANS=elif stands for “else if”. It checks another condition if the previous if condition was false.
#Example=
#if score>=90:
#   print("A")
#elif score>=80:
#   print("B")
#else:
#   print("C")

#Q13 What is the difference between for and while loop?
#ANS=•	for loop is used when you know how many times to repeat (like looping through a list).
#•	while loop is used when the number of repetitions depends on a condition.

#Q14 Describe a scenario where a while loop is more suitable than a for loop.
#ANS= Example: Asking a user to enter the correct password until they get it right.
#You don’t know how many tries they’ll need, so a while loop is better.
#Example
#Python=" "
#while password!="helloryan":
#    password=input("enter password:")
#print("access granted!")

#Practical quations of pyhton basic assignmenet 1

#Question1
#write a python program to print"hello,world!"
print("hello world")

#Question2
#write a python program that displays your name and age.
name=input("entre your name:")
age=input("enter your age:")
print(name)
print(age)

#question3
#write a code to print all the pre-defined keywords in python using the keyword library.
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))

#question4
#write a program that checks if a given words is a pyhton keywords.
import keyword
words=input("enter a pre-defined keyword")
if keyword.iskeyword(words):
    print("is a python keyword word:",words)
else:
    print("is not a pyhton keyword word:",words)

#question5
#create a list and tuple in python and demonstrate how attempting to change an element works differently for each.
#list
my_list=[1,2,3,4]
print("original list:",my_list)
my_list[0]=4
print("update list is:",my_list)
#tuple
#y_tuple={1,2,3,4}
#rint("original is:",my_tuple)
#y_tuple[2]=8
#rint("updated tuple is:",my_tuple)
#in tuple we cennot change the value because tuple is immutable

#question6
#write a function to demonstrate the behaviour of mutable and immutable arguments
#lists are mutable
def mutable_immutable(list,tuple):
    my_list=[1,2,3,4]
    print("my list is:",my_list)
#assigning new value to my list at index 0
    my_list[0]=8
    my_list2=my_list
    print("my new list is:",my_list2)
#try to print tuple now
    my_tuple={1,2,3,4}
    print("my tuple is:",my_tuple)
#assigning new or updated value to my value at index 0
    #my_tuple[0]=8
    #my_tuple2=my_tuple
    #print("my new tuple is:",my_tuple2)
mutable_immutable([],{})

#question7
#write a program that performs basic arthematic operarions on two user input.
x=int(input("enter a number:"))
y=int(input("enter a number:"))
print("sum is:",x+y)
print("differnce is:",x-y)
print("multiplication is:",x*y)
print("division is:",x/y)

#question8
#write a program to demonstrate the use of logical operator.
#logical operator are "AND","OR","NOT".
x=int(input("enter a number:"))
y=int(input("enter a number:"))
#and operator both should be true otherwise i will count as false
if (x>0 and y>0):
    print("AND: both numbers should be positive(True)")
else:
    print("AND: if any one gets odd print (false)")

#or operator one should be true
if (x>0 or y>0):
    print("True: both or any one number should be positive(True)")
else:
    print("True: both odd print(False)")

#not operator
if (x>0):
    print("NOT: x is not posiive")
else:
    print("NOT: x is positive")


#question9
#write a python program to convert user input from string to integer , float and boolean types.
x=input("entre a number:")
int_val=int(x)
print("int value is:",int_val)
float_val=float(int_val)
print("float value is:",float_val)
boolean_val=bool(float_val)
print("boolean value is:",boolean_val)

#question10
#write a code to demonstrate type casting with list elements.
my_list=["1","2","3","4"]
print("my list is:",my_list)
int_list=[int(x) for x in my_list] #list comprehension
print("new list is:",int_list)
for x in int_list:
    print(f"value:{x},type:{type(x)}")
float_list=[float(x) for x in int_list]
print("2nd new list is:",float_list)
for x in float_list:
    print(f"value:{x},type:{type(x)}")

#question11
#write a program that checks if a number is positive, negative or zero.
num=int(input("enter a number:"))
if num>0:
    print("the number is positive:")
elif num<0:
    print("the number is negative:")
elif num==0:
    print("the number is zero:")

#question12
#write a for loop to print numbers from 1 to 10
for i in range(1,11):
    print(i)

#Theory questions of assignment 1

#what is python and why is it popular?
#ANS=Python is a high-level, interpreted programming language known for its simple and readable syntax.
#why its popular:
#	Easy to learn and write
#	Large community support
#	Wide range of libraries (for web, data science, AI, etc.)
#	Used in many fields like web development, automation, and machine learning

#Q2 What is an interpreter in python?
#ANS=An interpreter in Python is a program that reads and runs Python code line by line.
# It converts high-level code into machine-readable instructions during execution.

#Q3 What are pre-defined keywords in python?
#ANS=Pre-defined keywords are reserved words that have special meaning in Python.
#Examples: if, else, while, for, def, class, etc.

#Q4 Can keywords be used as variable names?
#ANS=No, you cannot use keywords as variable names in Python.
#for example:if=5.

#Q5 What is mutability in python?
#ANS=Mutability refers to whether an object can be changed after it is created.
#•	Mutable objects can be modified (like lists).
#•	Immutable objects cannot be changed (like strings, tuples).

#Q6 Why are lists mutable,but tuples are immutable?
#ANS=	Lists are designed to be flexible, so you can add, remove, or change elements.
	#Tuples are meant to be fixed collections of items for safety and performance, so their contents can’t be changed.

#Q7 What is the difference between == and is operator in python?
#ANS= •	== checks if values are equal.
#is checks if both variables refer to the same object in memory.
#example a=[1,2] , b=[1,2]
# a== b is True
# a is b is False

#Q8 what are logical operator in python?
#ANS= Logical operators are used to combine conditions:
#•	and – returns True if both are True
#•	or – returns True if at least one is True
#•	not – reverses the result (True becomes False)

#Q9 What is type casting in python?
#ANS=Type casting means converting one data type into another.
#Example: a="10"
#         b=int(a)

#Q10 What is the difference between implicit and explicit type casting?
#ANS= Implicit is done automatically by Python.
#Example=5+2.0 result=7.0
# Explicit cating is done manually b the programmer.
#Example=int("10") or str(5).

#Q11 What is the purpose of conditional statement in python?
#ANS= Conditional statements are used to make decisions in code.
#They execute different blocks based on whether conditions are True or False.
#Example :
#if age>18:
#   print("adult")
#else:
#   print("minor")

#Q12 How does the elif statement work?
#ANS=elif stands for “else if”. It checks another condition if the previous if condition was false.
#Example=
#if score>=90:
#   print("A")
#elif score>=80:
#   print("B")
#else:
#   print("C")

#Q13 What is the difference between for and while loop?
#ANS=•	for loop is used when you know how many times to repeat (like looping through a list).
#•	while loop is used when the number of repetitions depends on a condition.

#Q14 Describe a scenario where a while loop is more suitable than a for loop.
#ANS= Example: Asking a user to enter the correct password until they get it right.
#You don’t know how many tries they’ll need, so a while loop is better.
#Example
#Python=" "
#while password!="helloryan":
#    password=input("enter password:")
#print("access granted!")

#Practical quations of assignmenet 1

#Question1
#write a python program to print"hello,world!"
print("hello world")

#Question2
#write a python program that displays your name and age.
name=input("entre your name:")
age=input("enter your age:")
print(name)
print(age)

#question3
#write a code to print all the pre-defined keywords in python using the keyword library.
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))

#question4
#write a program that checks if a given words is a pyhton keywords.
import keyword
words=input("enter a pre-defined keyword")
if keyword.iskeyword(words):
    print("is a python keyword word:",words)
else:
    print("is not a pyhton keyword word:",words)

#question5
#create a list and tuple in python and demonstrate how attempting to change an element works differently for each.
#list
my_list=[1,2,3,4]
print("original list:",my_list)
my_list[0]=4
print("update list is:",my_list)
#tuple
#y_tuple={1,2,3,4}
#rint("original is:",my_tuple)
#y_tuple[2]=8
#rint("updated tuple is:",my_tuple)
#in tuple we cennot change the value because tuple is immutable

#question6
#write a function to demonstrate the behaviour of mutable and immutable arguments
#lists are mutable
def mutable_immutable(list,tuple):
    my_list=[1,2,3,4]
    print("my list is:",my_list)
#assigning new value to my list at index 0
    my_list[0]=8
    my_list2=my_list
    print("my new list is:",my_list2)
#try to print tuple now
    my_tuple={1,2,3,4}
    print("my tuple is:",my_tuple)
#assigning new or updated value to my value at index 0
    #my_tuple[0]=8
    #my_tuple2=my_tuple
    #print("my new tuple is:",my_tuple2)
mutable_immutable([],{})

#question7
#write a program that performs basic arthematic operarions on two user input.
x=int(input("enter a number:"))
y=int(input("enter a number:"))
print("sum is:",x+y)
print("differnce is:",x-y)
print("multiplication is:",x*y)
print("division is:",x/y)

#question8
#write a program to demonstrate the use of logical operator.
#logical operator are "AND","OR","NOT".
x=int(input("enter a number:"))
y=int(input("enter a number:"))
#and operator both should be true otherwise i will count as false
if (x>0 and y>0):
    print("AND: both numbers should be positive(True)")
else:
    print("AND: if any one gets odd print (false)")

#or operator one should be true
if (x>0 or y>0):
    print("True: both or any one number should be positive(True)")
else:
    print("True: both odd print(False)")

#not operator
if (x>0):
    print("NOT: x is not posiive")
else:
    print("NOT: x is positive")


#question9
#write a python program to convert user input from string to integer , float and boolean types.
x=input("entre a number:")
int_val=int(x)
print("int value is:",int_val)
float_val=float(int_val)
print("float value is:",float_val)
boolean_val=bool(float_val)
print("boolean value is:",boolean_val)

#question10
#write a code to demonstrate type casting with list elements.
my_list=["1","2","3","4"]
print("my list is:",my_list)
int_list=[int(x) for x in my_list] #list comprehension
print("new list is:",int_list)
for x in int_list:
    print(f"value:{x},type:{type(x)}")
float_list=[float(x) for x in int_list]
print("2nd new list is:",float_list)
for x in float_list:
    print(f"value:{x},type:{type(x)}")

#question11
#write a program that checks if a number is positive, negative or zero.
num=int(input("enter a number:"))
if num>0:
    print("the number is positive:")
elif num<0:
    print("the number is negative:")
elif num==0:
    print("the number is zero:")

#question12
#write a for loop to print numbers from 1 to 10
for i in range(1,11):
    print(i)

#question13
#write a python program to find the sum of all even numbers between 1 to 50
count=1
total=0
while count<50:
    if count%2==0:
        total+=count
    print("even")
    count+=1
    print("sum of even numbers from 1 to 50 is:",total)

#question14
#write a program to reverse a string using while loop.
text=input("enter a string:")
reversed_text=""
index = len(text)-1
while index>=0:
    reversed_text+=text[index]
    index-=1
print("reversed string is:",reversed_text)

#question15
#write a python program to calculate the factorial of a number provided by the user using a while loop.
num=int(input("enter a number:"))
factorial=1
count=1
while count <=num:
    factorial=factorial*count
    count+=1
print("factorial of",num, "is:",factorial)
# Out:
# hello world
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1-902341110.py in <cell line: 0>()
#      94 #Question2
#      95 #write a python program that displays your name and age.
# ---> 96 name=input("entre your name:")
#      97 age=input("enter your age:")
#      98 print(name)
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
